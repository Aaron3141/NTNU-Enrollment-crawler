# %% [markdown]
# <b><a href="http://localhost:8888/terminals/1"> Open terminal</a></b>
#
# <ul>
# <li><b>cd</b> current pwd</li>
# <li><b>conda activate</b> crawler</li>
# <li><b>python</b> getCookies.py</li>
# <li><b>put</b> cookies value in cookieValue</li>
# </ul>

# %%
cookieValue = '1nGmpytKzTpj1rjLHXgjLxZxB9XMLpHh3mnbHzpK5V2VbSBJt3Mx!407899233'

# %%
import requests
import urllib
import personalInf

# %%
cookie = {
    "domain": "cos1.ntnu.edu.tw",
    "hostOnly": "true",
    "httpOnly": "true",
    "name": "JSESSIONID",
    "path": "/",
    "sameSite": "unspecified",
    "secure": "false",
    "session": "true",
    "storeId": "0",
    "value": cookieValue,
    "id": "1"
}
# JSESSIONID
# BZRTpnpZM4zknts4JTtntKYYv3ynDP6nJp6wJkZCnjLnz1HxT7x9!407899233
# driver.get_cookies()[0]["value"]
# print(cookie)

# %%
session = requests.Session()
hhGet = {
    "Host": "cos1.ntnu.edu.tw",
    "Connection": "keep-alive",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36",
    "Accept": "*/*",
    "Referer": "http://cos1.ntnu.edu.tw/AasEnrollStudent/IndexCtrl?language=TW",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9,zh-TW;q=0.8,zh-CN;q=0.7,zh;q=0.6,ja;q=0.5,ko;q=0.4",
    "Cookie": "JSESSIONID={}".format(cookieValue),
    "dnt": "1"
}

# %%
urlGetUserCourse = "http://cos1.ntnu.edu.tw/AasEnrollStudent/StfseldListCtrl"
dataGetUserCourse = {
    "action": "showGrid",
    "_dc": "1579631355794",
    "page": "1",
    "start": "0",
    "limit": "999999",
    "group": "[{\"property\":\"v_totalCredit\",\"direction\":\"ASC\"}]",
    "sort": "[{\"property\":\"v_totalCredit\",\"direction\":\"ASC\"}]"
}
urlGetUserCourse = urlGetUserCourse + "?" + urllib.parse.urlencode(dataGetUserCourse)
print(urlGetUserCourse)

UserCourse = session.get(urlGetUserCourse, headers = hhGet)
# , cookies=cookie
# Out:
# http://cos1.ntnu.edu.tw/AasEnrollStudent/StfseldListCtrl?action=showGrid&_dc=1579631355794&page=1&start=0&limit=999999&group=%5B%7B%22property%22%3A%22v_totalCredit%22%2C%22direction%22%3A%22ASC%22%7D%5D&sort=%5B%7B%22property%22%3A%22v_totalCredit%22%2C%22direction%22%3A%22ASC%22%7D%5D

# %%
UserCourse.text

# %%
hhSearch = {
    "Host": "cos1.ntnu.edu.tw",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Referer": "http://cos1.ntnu.edu.tw/AasEnrollStudent/StfseldListCtrl",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9",
    "Cookie": "JSESSIONID={}".format(str(driver.get_cookies()[0]["value"]))
}
ressget = requests.get("http://cos1.ntnu.edu.tw/AasEnrollStudent/CourseQueryCtrl?action=query", headers = hhSearch)

# %%
dd = {
    "serialNo": "",
    "chnName": "",
    "teacher": "",
    "deptCode": "SU40",
    "formS": "",
    "class1": "",
    "generalCore": "",
    "notFull": "",
    "courseCode": "",
    "checkWkSection10": "0",
    "checkWkSection11": "0",
    "checkWkSection12": "0",
    "checkWkSection13": "0",
    "checkWkSection14": "0",
    "checkWkSection15": "0",
    "checkWkSection16": "0",
    "checkWkSection17": "0",
    "checkWkSection18": "0",
    "checkWkSection19": "0",
    "checkWkSection110": "0",
    "checkWkSection111": "0",
    "checkWkSection112": "0",
    "checkWkSection113": "0",
    "checkWkSection114": "0",
    "checkWkSection20": "0",
    "checkWkSection21": "0",
    "checkWkSection22": "0",
    "checkWkSection23": "0",
    "checkWkSection24": "0",
    "checkWkSection25": "0",
    "checkWkSection26": "0",
    "checkWkSection27": "0",
    "checkWkSection28": "0",
    "checkWkSection29": "0",
    "checkWkSection210": "0",
    "checkWkSection211": "0",
    "checkWkSection212": "0",
    "checkWkSection213": "0",
    "checkWkSection214": "0",
    "checkWkSection30": "0",
    "checkWkSection31": "0",
    "checkWkSection32": "0",
    "checkWkSection33": "0",
    "checkWkSection34": '0',
    "checkWkSection35": "0",
    "checkWkSection36": "0",
    "checkWkSection37": "0",
    "checkWkSection38": "0",
    "checkWkSection39": "0",
    "checkWkSection310": "0",
    "checkWkSection311": "0",
    "checkWkSection312": "0",
    "checkWkSection313": "0",
    "checkWkSection314": "0",
    "checkWkSection40": "0",
    "checkWkSection41": "0",
    "checkWkSection42": "0",
    "checkWkSection43": "0",
    "checkWkSection44": "0",
    "checkWkSection45": "0",
    "checkWkSection46": "0",
    "checkWkSection47": "0",
    "checkWkSection48": "0",
    "checkWkSection49": "0",
    "checkWkSection410": "0",
    "checkWkSection411": "0",
    "checkWkSection412": "0",
    "checkWkSection413": "0",
    "checkWkSection414": "0",
    "checkWkSection50": "0",
    "checkWkSection51": "0",
    "checkWkSection52": "0",
    "checkWkSection53": "0",
    "checkWkSection54": "0",
    "checkWkSection55": "0",
    "checkWkSection56": "0",
    "checkWkSection57": "0",
    "checkWkSection58": "0",
    "checkWkSection59": "0",
    "checkWkSection510": "0",
    "checkWkSection511": "0",
    "checkWkSection512": "0",
    "checkWkSection513": "0",
    "checkWkSection514": "0",
    "checkWkSection60": "0",
    "checkWkSection61": "0",
    "checkWkSection62": "0",
    "checkWkSection63": "0",
    "checkWkSection64": "0",
    "checkWkSection65": "0",
    "checkWkSection66": "0",
    "checkWkSection67": "0",
    "checkWkSection68": "0",
    "checkWkSection69": "0",
    "checkWkSection610": "0",
    "checkWkSection611": "0",
    "checkWkSection612": "0",
    "checkWkSection613": "0",
    "checkWkSection614": "0",
    'action': 'showGrid',
    'actionButton': 'query',
    "page": "1",
    "start": "0",
    "limit": "999999"
}
hhSearch = {
    "Host": "cos1.ntnu.edu.tw",
    "Connection": "keep-alive",
    "Content-Length": "62",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "Origin": "http://cos1.ntnu.edu.tw",
    "Referer": "http://cos1.ntnu.edu.tw/AasEnrollStudent/CourseQueryCtrl?action=query",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9",
    "Cookie": "JSESSIONID={}".format(str(driver.get_cookies()[0]["value"]))
}
# requests.post("http://cos1.ntnu.edu.tw/AasEnrollStudent/CourseQueryCtrl?action=showGrid", data={"page": "1", "start": "0", "limit": "999999"}, headers = hhSearch)

# %%
res2 = requests.post("http://cos1.ntnu.edu.tw/AasEnrollStudent/CourseQueryCtrl?action=showGrid", data=dd, headers = hhSearch)

# %%
res2.text
# Out:
# '{"Count":68,"List":[{"acadmTerm":"2","acadmYear":"108","applyCode":"","authorizeP":20,"chnName":"應用統計方法（一）","class1":"","courseCode":"MAU0062","courseGroup":"","courseKind":"半","credit":"3.0","deptCode":"SU40","deptGroup":"","domain":"","engName":"Applied Statistical Methods (I)","engTeach":"否","formS":"","insDeptCode":"SU40","limitCountH":50,"moocs":"N","optionCode":"選修","serialNo":"2644","sex_restrict":"","summerPhase":"","teacher":"蔡碧紋","timeInfo":"一 2-4 公館 Ｃ002","v_chn_name":"應用統計方法（一）","v_class1":"","v_comment":"","v_deptChiabbr":"數學系","v_deptGroup":"","v_error":"","v_is_Full":"","v_limitCourse":"","v_phase":"","v_priority":0,"v_release_time":"","v_reserve_count":0,"v_stage":0,"v_stfseld":19,"v_stfseld_auth":0,"v_stfseld_deal":0,"v_stfseld_exchange":0,"v_stfseld_undeal":19,"v_stfseld_unfull":0},{"acadmTerm":"2","acadmYear":"108","applyCode":"","authorizeP":20,"chnName":"微積分乙（二）","class1":"","courseCode":"MAU0181","courseGroup":"K","courseKind":"半","credit":"3.0","deptCode":"SU4
# ...

# %%
# need a get method
hhGetSch = {
    "Host": "cos1.ntnu.edu.tw",
    "Connection": "keep-alive",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36",
    "Accept": "*/*",
    "Referer": "http://cos1.ntnu.edu.tw/AasEnrollStudentNew/CourseQueryCtrl?action=querySchool",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9",
    "Cookie": "JSESSIONID={}".format(str(driver.get_cookies()[0]["value"]))
}
uu = "http://cos1.ntnu.edu.tw/AasEnrollStudentNew/CourseQueryCtrl?action=showGrid&_dc=1579643558792&serialNo=&chnName=&teacher=&deptCode=9DAA&formS=&class1=&notFull=0&courseCode=&checkWkSection10=0&checkWkSection11=0&checkWkSection12=0&checkWkSection13=0&checkWkSection14=0&checkWkSection15=0&checkWkSection16=0&checkWkSection17=0&checkWkSection18=0&checkWkSection19=0&checkWkSection110=0&checkWkSection111=0&checkWkSection112=0&checkWkSection113=0&checkWkSection114=0&checkWkSection20=0&checkWkSection21=0&checkWkSection22=0&checkWkSection23=0&checkWkSection24=0&checkWkSection25=0&checkWkSection26=0&checkWkSection27=0&checkWkSection28=0&checkWkSection29=0&checkWkSection210=0&checkWkSection211=0&checkWkSection212=0&checkWkSection213=0&checkWkSection214=0&checkWkSection30=0&checkWkSection31=0&checkWkSection32=0&checkWkSection33=0&checkWkSection34=0&checkWkSection35=0&checkWkSection36=0&checkWkSection37=0&checkWkSection38=0&checkWkSection39=0&checkWkSection310=0&checkWkSection311=0&checkWkSection312=0&checkWkSection313=0&checkWkSection314=0&checkWkSection40=0&checkWkSection41=0&checkWkSection42=0&checkWkSection43=0&checkWkSection44=0&checkWkSection45=0&checkWkSection46=0&checkWkSection47=0&checkWkSection48=0&checkWkSection49=0&checkWkSection410=0&checkWkSection411=0&checkWkSection412=0&checkWkSection413=0&checkWkSection414=0&checkWkSection50=0&checkWkSection51=0&checkWkSection52=0&checkWkSection53=0&checkWkSection54=0&checkWkSection55=0&checkWkSection56=0&checkWkSection57=0&checkWkSection58=0&checkWkSection59=0&checkWkSection510=0&checkWkSection511=0&checkWkSection512=0&checkWkSection513=0&checkWkSection514=0&checkWkSection60=0&checkWkSection61=0&checkWkSection62=0&checkWkSection63=0&checkWkSection64=0&checkWkSection65=0&checkWkSection66=0&checkWkSection67=0&checkWkSection68=0&checkWkSection69=0&checkWkSection610=0&checkWkSection611=0&checkWkSection612=0&checkWkSection613=0&checkWkSection614=0&action=showGrid&actionButton=querySchool&page=1&start=0&limit=999999"
uuss = session.get(uu, headers = hhGetSch)

# %%
uuss.text
# Out:
# '\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<META NAME="ROBOTS" CONTENT="NOINDEX, NOFOLLOW">\n<link rel="stylesheet" type="text/css" href="js/extjs420/resources/css/ext-all.css">\n<link rel="stylesheet" type="text/css" href="css/ntnu-AasEnrollStudent.css">\n<!--<link rel="stylesheet" type="text/css" href="css/ext-patch.css">-->\n<!--<script type="text/javascript" src="js/extjs/adapter/ext/ext-base.js"></script>-->\n<script type="text/javascript" src="js/extjs420/ext-all.js"></script>\n<script type="text/javascript" src="js/common.js"></script>\n<!--\n<script type="text/javascript" src="js/extjs/source/local/ext-lang-zh_TW.js" charset="UTF-8"></script>\n-->\n<!--<script type="text/javascript" src="js/extjs/courseGrid.js"></script>-->\n<!--<script type="text/javascript" src="js/extjs/GroupSummary.js"></script>-->\n\n<script language=JavaScript>\n          var gridHeight;\n          var requestTime,requestSecond ;\n          requestSecond = 17*1000*60;\
# ...

# %%
driver.close()
